# %% [markdown]
# <a href="https://colab.research.google.com/github/thanga-v2/Exploratory-Data-Analysis/blob/main/Folium_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium

# %%
import folium
from folium.plugins import MarkerCluster, MiniMap
# Define the coordinates for India
India_cords = [20.5937,78.9629]

# Create a map centered on India
m = folium.Map(location=India_cords,
               zoom_start=5,
               attr="Geographic Analysis - Fasta Pizza Outlets across India")

# Add markers for some major cities in India
cities = [
    {"name": "Bangalore", "coordinates":[12.9716,77.5946],"population": "18 million", "shop address": "Bnglore street", "revenue": "2.56 million"},
    {"name": "Alandur", "coordinates": [13.004202,80.201471], "population": "18 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Vadapalani", "coordinates": [13.052192, 80.212051], "population": "10 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Adayar", "coordinates": [13.003387, 80.255043], "population": "7 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Trivandrum", "coordinates":[8.5241,76.9366]},
    {"name": "Mumbai", "coordinates":[19.0760,	72.8777]},
    {"name" :"Vizag", "coordinates" : [17.6868,	83.2185]},
    {"name" :"Delhi", "coordinates" : [28.7041,	77.1025]},
    {"name" :"Coimbatore", "coordinates" : [11.0168,	76.9558]},
    {"name" :"Nagpur", "coordinates" : [21.1458,	79.0882]},
    {"name" :"Agra", "coordinates" : [27.1767,	78.0081]},
    {"name" :"Darjeeling", "coordinates" : [27.0360,88.2627]},
    {"name" :"Varanasi", "coordinates" : [25.3176,82.9739]},
    {"name" :"Kakinada", "coordinates" : [16.9891,82.2475]},
    {"name" :"Hyderabad", "coordinates" : [17.3850,78.4867]},
    {"name" :"Jaipur", "coordinates" : [26.9124,75.7873]},
    {"name" :"Amritsar", "coordinates" : [31.6338,74.8723]},
    {"name" :"Kolkatta", "coordinates" : [22.5726,88.3639]},
    {"name" :"Faridabad", "coordinates" : [28.4089,77.3178]},
    {"name":"Surat", "coordinates":[21.1702,72.8311]},
    {"name":"Kanpur",	"coordinates":[26.4499,80.3319]},
    {"name":"Coimbatore",	"coordinates":	[11.0168,76.9558]},
    {"name":"Surat",	"coordinates":[21.1702,72.8311]},
    {"name":"Kanpur",	"coordinates":[26.4499,80.3319]},
    {"name":"Coimbatore",	"coordinates":[11.0168,76.9558]},
  {"name":"Mysore",	"coordinates":[12.2958,76.6394]},
{"name":"Ernakulam",	"coordinates":[9.9816,76.2999]},
{"name":"Vijayawada",	"coordinates":[16.5062,80.6480]},
{"name":"Ranga Reddy City",	"coordinates":[17.2786,78.3179]},
{"name":"Pune",	"coordinates":[18.5204,73.8567]},
{"name":"Jodhpur",	"coordinates":[26.2389,73.0243]},
{"name":"Ludhiana",	"coordinates":[30.9000,75.8573]},
{"name":"Nadia",	"coordinates":[23.4065,88.4345]},
{"name":"Delhi NCR",	"coordinates":[28.6139,77.2090]},
{"name":"Gurugram",	"coordinates":[28.4595,77.0266]},
{"name":"Ahmedabad",	"coordinates":[23.0225,72.5714]},
{"name":"Lucknow",	"coordinates":[26.8467,80.9462]},
{"name":"Trichy (Tiruchirappalli)",	"coordinates":[10.7905,78.7047]},
{"name":"Dharwad",	"coordinates":[15.4589,75.0078]},
{"name":"Kozhikode",	"coordinates":[11.2588,75.7804]},
{"name":"Tirupati",	"coordinates":[13.6288,79.4192]},
{"name":"Warangal",	"coordinates":[17.9784,79.5941]},
{"name":"Nagpur",	"coordinates":[21.1458,79.0882]},
{"name":"Kota",	"coordinates":[25.2138,75.8648]},
{"name":"Jalandhar",	"coordinates":[31.3260,75.5762]},
{"name":"Howrah",	"coordinates":[22.5958,88.2636]},
{"name":"Noida",	"coordinates":[28.5355,77.3910]},
{"name":"Panipat",	"coordinates":[29.3909,76.9635]},
{"name":"Vadodara",	"coordinates":[22.3072,73.1812]},
{"name":"Agra",	"coordinates":[27.1767,78.0081]},
{"name":"Madurai",	"coordinates":[9.9252,78.1198]},
{"name":"Kalaburagi (Gulbarga)",	"coordinates":[17.3297,76.8343]},
{"name":"Cochin",	"coordinates":[9.9312,76.2673]},
{"name":"Nellore",	"coordinates":[14.4426,79.9865]},
{"name":"Nizamabad",	"coordinates":[18.6725,78.0941]},
{"name":"Thane",	"coordinates":[19.2183,72.9781]},
{"name":"Bikaner",	"coordinates":[28.0229,73.3119]},
{"name":"Patiala",	"coordinates":[30.3398,76.3869]},
{"name":"Hooghly",	"coordinates":[22.8966,88.3993]},
{"name":"Noida NCR",	"coordinates":[28.5355,77.3910]},
{"name":"Yamuna Nagar",	"coordinates":[30.1290,77.2841]},
{"name":"Rajkot",	"coordinates":[22.3039,70.8022]},
{"name":"Meerut",	"coordinates":[28.9845,77.7064]},
{"name":"Thirunelveli",	"coordinates":[8.7139,77.7567]},
{"name":"Dakshina Kannada",	"coordinates":[12.8673,75.3670]},
{"name":"Kollam",	"coordinates":[8.8932,76.6141]},
{"name":"Kurnool",	"coordinates":[15.8281,78.0373]},
{"name":"Khammam",	"coordinates":[17.2473,80.1431]},
{"name":"Nashik",	"coordinates":[19.9975,73.7898]},
{"name":"Bhiwadi",	"coordinates":[28.2107,76.8606]},
{"name":"SAS Nagar (Mohali)",	"coordinates":[30.7046,76.7179]},
{"name":"Darjeeling",	"coordinates":[27.0360,88.2627]},
{"name":"Jamnagar",	"coordinates":[22.4707,70.0577]},
{"name":"Varanasi",	"coordinates":[25.3176,82.9739]},
{"name":"Salem",	"coordinates":[11.6643,78.1460]},
{"name":"Belagavi (Belgaum)",	"coordinates":[15.8497,74.4977]},
{"name":"Thrissur", "coordinates":[10.5276,76.2144]},
{"name":"Kakinada",	"coordinates":[16.9891,82.2475]},
{"name":"Karimnagar",	"coordinates":[18.4386,79.1288]},
{"name":"Palghar",	"coordinates":[19.6951,72.7656]},
{"name":"Udaipur",	"coordinates":[24.5854,73.7125]},
{"name":"Nadia",	"coordinates":[23.4065,88.4345]},
{"name":"Gandhinagar",	"coordinates":[23.2156,72.6369]},
{"name":"Ghaziabad",	"coordinates":[28.6692,77.4538]},
{"name":"Erode",	"coordinates":[11.3410,77.7172]},
{"name":"Davanagere",	"coordinates":[14.4645,75.9238]},
{"name":"Kannur",	"coordinates":[11.8745,75.3704]},
{"name":"Godavari (East)",	"coordinates":[16.9856,82.2386]},
{"name":"Mahabubnagar",	"coordinates":[16.7350,77.9840]},
{"name":"Aurangabad",	"coordinates":[19.8762,75.3433]},
{"name":"Ajmer",	"coordinates":[26.4499,74.6399]},
{"name":"Jalpaiguri",	"coordinates":[26.5453,88.7196]},
{"name":"Gorakhpur",	"coordinates":[26.7606,83.3732]},
{"name":"Tirupur",	"coordinates":[11.1085,77.3411]},
{"name":"Ballari (Bellary)",	"coordinates":[15.1394,76.9214]},
{"name":"Malappuram", "coordinates":[11.0739,76.0742]},
{"name":"Kadapa",	"coordinates":[14.4673,78.8242]},
{"name":"Nalgonda",	"coordinates":[17.0544,79.2684]},
{"name":"Solapur",	"coordinates":[17.6599,75.9064]},
{"name":"Jhansi",	"coordinates":[25.4484,78.5696]},
{"name":"Nagercoil",	"coordinates":[8.1780,77.4289]},
{"name":"Hubli (Hubballi)",	"coordinates":[15.3647,75.1239]},
{"name":"Alappuzha",	"coordinates":[9.4981,76.3388]}
]

# Add markers for each city
for city in cities:
    folium.Marker(
        location=city["coordinates"],
        popup=f"<b>{city['name']}</b><br> ",
        tooltip=city["name"],
        icon=folium.Icon(color="orange")
        ).add_to(m)

# Save the map to an HTML file
m.save("india_map.html")

# Display the map in a Jupyter notebook (if applicable)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium.plugins import MarkerCluster, MiniMap

# Create a map centered at some location (for example, India)
m = folium.Map(
    location=[20.5937, 78.9629],
    zoom_start=5,
    tiles="Stamen Terrain",
    attr="Geographic Analysis - Fasta Pizza Outlets across India"
)

# Example cities with coordinates (add your actual data)
cities = [
    {"name": "Bangalore", "coordinates":[12.9716,77.5946],"population": "18 million", "shop address": "Bnglore street", "revenue": "2.56 million"},
    {"name": "Alandur", "coordinates": [13.004202,80.201471], "population": "18 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Vadapalani", "coordinates": [13.052192, 80.212051], "population": "10 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Adayar", "coordinates": [13.003387, 80.255043], "population": "7 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Trivandrum", "coordinates":[8.5241,76.9366]},
    {"name": "Mumbai", "coordinates":[19.0760,	72.8777]},
    {"name" :"Vizag", "coordinates" : [17.6868,	83.2185]},
    {"name" :"Delhi", "coordinates" : [28.7041,	77.1025]},
    {"name" :"Coimbatore", "coordinates" : [11.0168,	76.9558]},
    {"name" :"Nagpur", "coordinates" : [21.1458,	79.0882]},
    {"name" :"Agra", "coordinates" : [27.1767,	78.0081]},
    {"name" :"Darjeeling", "coordinates" : [27.0360,88.2627]},
    {"name" :"Varanasi", "coordinates" : [25.3176,82.9739]},
    {"name" :"Kakinada", "coordinates" : [16.9891,82.2475]},
    {"name" :"Hyderabad", "coordinates" : [17.3850,78.4867]},
    {"name" :"Jaipur", "coordinates" : [26.9124,75.7873]},
    {"name" :"Amritsar", "coordinates" : [31.6338,74.8723]},
    {"name" :"Kolkatta", "coordinates" : [22.5726,88.3639]},
    {"name" :"Faridabad", "coordinates" : [28.4089,77.3178]},
    {"name":"Surat", "coordinates":[21.1702,72.8311]},
    {"name":"Kanpur",	"coordinates":[26.4499,80.3319]},
    {"name":"Coimbatore",	"coordinates":	[11.0168,76.9558]},
    {"name":"Surat",	"coordinates":[21.1702,72.8311]},
    {"name":"Kanpur",	"coordinates":[26.4499,80.3319]},
    {"name":"Coimbatore",	"coordinates":[11.0168,76.9558]},
  {"name":"Mysore",	"coordinates":[12.2958,76.6394]},
{"name":"Ernakulam",	"coordinates":[9.9816,76.2999]},
{"name":"Vijayawada",	"coordinates":[16.5062,80.6480]},
{"name":"Ranga Reddy City",	"coordinates":[17.2786,78.3179]},
{"name":"Pune",	"coordinates":[18.5204,73.8567]},
{"name":"Jodhpur",	"coordinates":[26.2389,73.0243]},
{"name":"Ludhiana",	"coordinates":[30.9000,75.8573]},
{"name":"Nadia",	"coordinates":[23.4065,88.4345]},
{"name":"Delhi NCR",	"coordinates":[28.6139,77.2090]},
{"name":"Gurugram",	"coordinates":[28.4595,77.0266]},
{"name":"Ahmedabad",	"coordinates":[23.0225,72.5714]},
{"name":"Lucknow",	"coordinates":[26.8467,80.9462]},
{"name":"Trichy (Tiruchirappalli)",	"coordinates":[10.7905,78.7047]},
{"name":"Dharwad",	"coordinates":[15.4589,75.0078]},
{"name":"Kozhikode",	"coordinates":[11.2588,75.7804]},
{"name":"Tirupati",	"coordinates":[13.6288,79.4192]},
{"name":"Warangal",	"coordinates":[17.9784,79.5941]},
{"name":"Nagpur",	"coordinates":[21.1458,79.0882]},
{"name":"Kota",	"coordinates":[25.2138,75.8648]},
{"name":"Jalandhar",	"coordinates":[31.3260,75.5762]},
{"name":"Howrah",	"coordinates":[22.5958,88.2636]},
{"name":"Noida",	"coordinates":[28.5355,77.3910]},
{"name":"Panipat",	"coordinates":[29.3909,76.9635]},
{"name":"Vadodara",	"coordinates":[22.3072,73.1812]},
{"name":"Agra",	"coordinates":[27.1767,78.0081]},
{"name":"Madurai",	"coordinates":[9.9252,78.1198]},
{"name":"Kalaburagi (Gulbarga)",	"coordinates":[17.3297,76.8343]},
{"name":"Cochin",	"coordinates":[9.9312,76.2673]},
{"name":"Nellore",	"coordinates":[14.4426,79.9865]},
{"name":"Nizamabad",	"coordinates":[18.6725,78.0941]},
{"name":"Thane",	"coordinates":[19.2183,72.9781]},
{"name":"Bikaner",	"coordinates":[28.0229,73.3119]},
{"name":"Patiala",	"coordinates":[30.3398,76.3869]},
{"name":"Hooghly",	"coordinates":[22.8966,88.3993]},
{"name":"Noida NCR",	"coordinates":[28.5355,77.3910]},
{"name":"Yamuna Nagar",	"coordinates":[30.1290,77.2841]},
{"name":"Rajkot",	"coordinates":[22.3039,70.8022]},
{"name":"Meerut",	"coordinates":[28.9845,77.7064]},
{"name":"Thirunelveli",	"coordinates":[8.7139,77.7567]},
{"name":"Dakshina Kannada",	"coordinates":[12.8673,75.3670]},
{"name":"Kollam",	"coordinates":[8.8932,76.6141]},
{"name":"Kurnool",	"coordinates":[15.8281,78.0373]},
{"name":"Khammam",	"coordinates":[17.2473,80.1431]},
{"name":"Nashik",	"coordinates":[19.9975,73.7898]},
{"name":"Bhiwadi",	"coordinates":[28.2107,76.8606]},
{"name":"SAS Nagar (Mohali)",	"coordinates":[30.7046,76.7179]},
{"name":"Darjeeling",	"coordinates":[27.0360,88.2627]},
{"name":"Jamnagar",	"coordinates":[22.4707,70.0577]},
{"name":"Varanasi",	"coordinates":[25.3176,82.9739]},
{"name":"Salem",	"coordinates":[11.6643,78.1460]},
{"name":"Belagavi (Belgaum)",	"coordinates":[15.8497,74.4977]},
{"name":"Thrissur", "coordinates":[10.5276,76.2144]},
{"name":"Kakinada",	"coordinates":[16.9891,82.2475]},
{"name":"Karimnagar",	"coordinates":[18.4386,79.1288]},
{"name":"Palghar",	"coordinates":[19.6951,72.7656]},
{"name":"Udaipur",	"coordinates":[24.5854,73.7125]},
{"name":"Nadia",	"coordinates":[23.4065,88.4345]},
{"name":"Gandhinagar",	"coordinates":[23.2156,72.6369]},
{"name":"Ghaziabad",	"coordinates":[28.6692,77.4538]},
{"name":"Erode",	"coordinates":[11.3410,77.7172]},
{"name":"Davanagere",	"coordinates":[14.4645,75.9238]},
{"name":"Kannur",	"coordinates":[11.8745,75.3704]},
{"name":"Godavari (East)",	"coordinates":[16.9856,82.2386]},
{"name":"Mahabubnagar",	"coordinates":[16.7350,77.9840]},
{"name":"Aurangabad",	"coordinates":[19.8762,75.3433]},
{"name":"Ajmer",	"coordinates":[26.4499,74.6399]},
{"name":"Jalpaiguri",	"coordinates":[26.5453,88.7196]},
{"name":"Gorakhpur",	"coordinates":[26.7606,83.3732]},
{"name":"Tirupur",	"coordinates":[11.1085,77.3411]},
{"name":"Ballari (Bellary)",	"coordinates":[15.1394,76.9214]},
{"name":"Malappuram", "coordinates":[11.0739,76.0742]},
{"name":"Kadapa",	"coordinates":[14.4673,78.8242]},
{"name":"Nalgonda",	"coordinates":[17.0544,79.2684]},
{"name":"Solapur",	"coordinates":[17.6599,75.9064]},
{"name":"Jhansi",	"coordinates":[25.4484,78.5696]},
{"name":"Nagercoil",	"coordinates":[8.1780,77.4289]},
{"name":"Hubli (Hubballi)",	"coordinates":[15.3647,75.1239]},
{"name":"Alappuzha",	"coordinates":[9.4981,76.3388]}
]

# Add a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add markers for each city
for city in cities:
    folium.Marker(
        location=city["coordinates"],
        popup=f"<b>{city['name']}</b><br><img src='https://via.placeholder.com/100' alt='{city['name']} Image'>",
        tooltip=city["name"],
        icon=folium.Icon(color="orange", icon="info-sign")
    ).add_to(marker_cluster)

# Add a minimap
minimap = MiniMap(toggle_display=True, width=150, height=150)
m.add_child(minimap)
# Save the map
m.save("enhanced_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
