# %% [markdown]
# <a href="https://colab.research.google.com/github/thanga-v2/Exploratory-Data-Analysis/blob/main/Geo-Analysis-FastaPizza-Folium_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)

# %%
import folium

# Define the coordinates for India
tamilnadu_cords = [11.127123,78.656891]

# Create a map centered on India
m = folium.Map(location=tamilnadu_cords, zoom_start=5)

# Add markers for some major cities in India
cities = [
    {"name": "Bangalore", "coordinates":[12.9716,77.5946],"population": "18 million", "shop address": "Bnglore street", "revenue": "2.56 million"},
    {"name": "Alandur", "coordinates": [13.004202,80.201471], "population": "18 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Vadapalani", "coordinates": [13.052192, 80.212051], "population": "10 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Adayar", "coordinates": [13.003387, 80.255043], "population": "7 million", "shop address": "RK Salai", "revenue": "2.5 million"},
    {"name": "Trivandrum", "coordinates":[8.5241,76.9366]},
    {"name": "Mumbai", "coordinates":[19.0760,	72.8777]},
    {"name" :"Vizag", "coordinates" : [17.6868,	83.2185]},
    {"name" :"Delhi", "coordinates" : [28.7041,	77.1025]},
    {"name" :"Coimbatore", "coordinates" : [11.0168,	76.9558]},
    {"name" :"Nagpur", "coordinates" : [21.1458,	79.0882]},
    {"name" :"Agra", "coordinates" : [27.1767,	78.0081]},
    {"name" :"Darjeeling", "coordinates" : [27.0360,88.2627]},
    {"name" :"Varanasi", "coordinates" : [25.3176,82.9739]},
    {"name" :"Kakinada", "coordinates" : [16.9891,82.2475]},
    {"name" :"Tirupur", "coordinates" : [11.1085,	77.3411]}
]

# Add markers for each city
for city in cities:
    folium.Marker(
        location=city["coordinates"],
        popup=f"<b>{city['name']}</b><br> ",
        tooltip=city["name"]
    ).add_to(m)

# Save the map to an HTML file
m.save("india_map.html")

# Display the map in a Jupyter notebook (if applicable)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b73a203afa2b8c0c5242ad8219758175 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b73a203afa2b8c0c5242ad8219758175&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b73a203afa2b8c0c5242ad8219758175 = L.map(
#                 &quot;map_b73a203afa2b8c0c5242ad8219758175&quot;,
#                 {
#                     center: [11.127123, 78.656891],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed3f7dd56e404df0ccd85373dc35252a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed3f7dd56e404df0ccd85373dc35252a.addTo(map_b73a203afa2b8c0c5242ad8219758175);
#
#
#             var marker_a0f952a7fd1d172898b8484b15a6ad93 = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_b73a203afa2b8c0c5242ad8219758175);
#
#
#         var popup_753525526cfa11235bab8481a6c44ff8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ceba9e0385abfcbef1bc7e2993e72dbb = $(`&lt;div id=&quot;html_ceba9e0385abfcbef1bc7e2993e72dbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore&lt;/b&gt;&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_753525526cfa11235bab8481a6c44ff8.setContent(html_ceba9e0385abfcbef1bc7e2993e72dbb);
#
#
#
#         marker_a0f952a7fd1d172898b8484b15a6ad93.bindPopup(popup_753525526cfa11235bab8481a6c44ff8)
#         ;
#
#
#
#
#             marker_a0f952a7fd1d172898b8484b15a6ad93.bindTooltip(
#                 `&lt;div&gt;
#                      Bangalore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_58ea0a4d304fdca4e11197a942d2e0d4 = L.marker(
#                 [13.004202, 80.201471],
#                 {}
#             ).addTo(map_b73a203afa2b8c0c5242ad8219758175);
#
#
#         var popup_ad5b931fbacd8c0fcfddc1117c7cc1bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1848b5fea513adcbe7584f26e43d68ec = $(`&lt;div id=&quot;html_1848b5fea513adcbe7584f26e43d68ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Alandur&lt;/b&gt;&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_ad5b931fbacd8c0fcfddc1117c7cc1bc.setContent(html_1848b5fea513adcbe7584f26e43d68ec);
#
#
#
#         marker_58ea0a4d304fdca4e11197a942d2e0d4.bindPopup(popup_ad5b931fbacd8c0fcfddc1117c7cc1bc)
#         ;
#
#
#
#
#             marker_58ea0a4d304fdca4e11197a942d2e0d4.bindTooltip(
#                 `&lt;div&gt;
#                      Alandur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1f895e625775df9c7949f1cb032cde6c = L.marker(
#                 [13.052192, 80.212051],
#                 {}
#             ).addTo(map_b73a203afa2b8c0c5242ad8219758175);
#
#
#         var popup_a6ba1e81e78d91089dc42b2d6f7eb382 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08144677ab030e677fa2cb577ded5fd7 = $(`&lt;div id=&quot;html_08144677ab030e677fa2cb577ded5fd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vadapalani&lt;/b&gt;&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_a6ba1e81e78d91089dc42b2d6f7eb382.setContent(html_08144677ab030e677fa2cb577ded5fd7);
#
#
#
#         marker_1f895e625775df9c7949f1cb032cde6c.bindPopup(popup_a6ba1e81e78d91089dc42b2d6f7eb382)
#         ;
#
#
#
#
#             marker_1f895e625775df9c7949f1cb032cde6c.bindTooltip(
#                 `&lt;div&gt;
#                      Vadapalani
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0b637f44f74a80f2285599d51f1f091 = L.marker(
#                 [13.003387, 80.255043],
#                 {}
#             ).addTo(map_b73a203afa2b8c0c5242ad8219758175);
#
#
#         var popup_1759e411bfda3ebce0f7e9264d2d5f9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2803ffa9b2e372b35ee544d402756fa4 = $(`&lt;div id=&quot;html_2803ffa9b2e372b35ee544d402756fa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Adayar&lt;/b&gt;&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_1759e411bfda3ebce0f7e9264d2d5f9c.setContent(html_2803ffa9b2e372b35ee544d402756fa4);
#
#
#
#         marker_a0b637f44f74a80f2285599d51f1f091.bindPopup(popup_1759e411bfda3ebce0f7e9264d2d5f9c)
#         ;
#
#
#
#
#             marker_a0b637f44f74a80f2285599d51f1f091.bindTooltip(
#                 `&lt;div&gt;
#                      Adayar
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
